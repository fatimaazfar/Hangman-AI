# %% [markdown]
# # Bidirectional LSTM Model
# The model described is a deep neural network for sequence processing, likely aimed at tasks like text generation or sequence classification. It uses a combination of embedding, convolutional, recurrent (LSTM), and dense layers, structured as follows:
#
# 1. **Embedding Layer**: Maps integer indices (representing characters or words) to dense vectors of size 128. This layer learns to encode the input characters into vectors that capture semantic information.
#
# 2. **1D Convolutional Layer (Conv1D)**: Applies 128 filters of kernel size 3 with 'same' padding and ReLU activation. This layer extracts local feature patterns from the embedded character sequences.
#
# 3. **Bidirectional LSTM Layer**: Consists of LSTM units with 256 neurons each, processing the data in both forward and backward directions to capture dependencies from both past and future contexts. It regularizes the network using L2 regularization to prevent overfitting and returns sequences to allow subsequent layers to access the entire sequence output.
#
# 4. **Dropout Layer**: Applies a dropout rate of 0.4 to reduce overfitting by randomly setting a proportion of input units to 0 during training.
#
# 5. **TimeDistributed Dense Layer**: Applies a dense layer to every time-step of the input sequence, using a softmax activation function. This is typically used in sequence prediction problems, producing a probability distribution over the character set for each time step.
#
# The model uses categorical crossentropy as the loss function, Adam optimizer, and tracks accuracy as a performance metric. It includes an early stopping mechanism to prevent overfitting, halting training if the validation loss does not improve for three consecutive epochs and restoring the best model weights.
#
# Overall, this architecture combines the strengths of convolutional and recurrent neural networks, allowing it to efficiently process and predict sequences with temporal dependencies.

# %%
import numpy as np
from keras.layers import Conv1D, LSTM, Dense, TimeDistributed, Embedding, Dropout
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.layers import Bidirectional
import random

# Load and preprocess data
def load_data(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        words = file.read().splitlines()
    return words

def simulate_missing_letters(word, p_missing=0.4):
    """
    Randomly replace letters with '0' to simulate missing letters,
    with p_missing chance for each letter.
    """
    simulated_word = ''
    for char in word:
        simulated_word += '0' if random.random() < p_missing else char
    return simulated_word

def preprocess_data(words, char_to_int, max_word_length, p_missing=0.4):
    sequences = []
    targets = []
    for word in words:
        word_with_missing = simulate_missing_letters(word, p_missing)
        sequences.append([char_to_int[char] if char in char_to_int else char_to_int['0'] for char in word_with_missing])
        targets.append([char_to_int[char] for char in word])
    sequences = pad_sequences(sequences, maxlen=max_word_length, padding='post')
    targets = pad_sequences(targets, maxlen=max_word_length, padding='post')
    return sequences, targets

file_path = '/kaggle/input/english-words/words_250000_train.txt'
words = load_data(file_path)
chars = sorted(list(set(''.join(words) + '0')))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))
max_word_length = 32

X, y = preprocess_data(words, char_to_int, max_word_length)
y = to_categorical(y, num_classes=len(chars))

model = Sequential()
model.add(Embedding(input_dim=len(chars), output_dim=128, trainable=True))
model.add(Conv1D(filters=128, kernel_size=3, padding='same', activation='relu'))
model.add(Bidirectional(LSTM(256, return_sequences=True, kernel_regularizer=l2(0.001))))
model.add(Dropout(0.4))
model.add(TimeDistributed(Dense(len(chars), activation='softmax')))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='min', restore_best_weights=True)

model.fit(X, np.array(y), validation_split=0.2, epochs=20, batch_size=128, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 34s 21ms/step - accuracy: 0.8479 - loss: 0.6456 - val_accuracy: 0.9039 - val_loss: 0.3516
# Epoch 2/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 21ms/step - accuracy: 0.9101 - loss: 0.3163 - val_accuracy: 0.9062 - val_loss: 0.3429
# Epoch 3/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9129 - loss: 0.3045 - val_accuracy: 0.9069 - val_loss: 0.3428
# Epoch 4/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9144 - loss: 0.2978 - val_accuracy: 0.9076 - val_loss: 0.3417
# Epoch 5/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9158 - loss: 0.2927 - val_accuracy: 0.9082 - val_loss: 0.3430
# Epoch 6/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9170 - loss: 0.2883 - val_accuracy: 0.9094 - val_loss: 0.3414
# Epoch 7/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9177 - loss: 0.2852 - val_accuracy: 0.9095 - val_loss: 0.3422
# Epoch 8/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9184 - loss: 0.2828 - val_accuracy: 0.9101 - val_loss: 0.3420
# Epoch 9/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9188 - loss: 0.2812 - val_accuracy: 0.9100 - val_loss: 0.3413
# Epoch 10/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9194 - loss: 0.2794 - val_accuracy: 0.9104 - val_loss: 0.3427
# Epoch 11/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 29s 21ms/step - accuracy: 0.9200 - loss: 0.2770 - val_accuracy: 0.9102 - val_loss: 0.3500
# Epoch 12/20
# 1421/1421 ━━━━━━━━━━━━━━━━━━━━ 30s 21ms/step - accuracy: 0.9205 - loss: 0.2760 - val_accuracy: 0.9106 - val_loss: 0.3440
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
model.summary()
# Out:
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_18 (Embedding)        │ (None, 45, 128)        │         3,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_17 (Conv1D)              │ (None, 45, 128)        │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_20                │ (None, 45, 512)        │       788,480 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 45, 512)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_17             │ (None, 45, 27)         │        13,851 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,565,203 (9.79 MB)
#  Trainable params: 855,067 (3.26 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,710,136 (6.52 MB)

# %% [markdown]
# # Load the trained model

# %%
from keras.models import load_model

# model.save('lstm_model_bi_5.h5')
model = load_model('/kaggle/input/anas-lstm/lstm.h5')

# %% [markdown]
# # LSTM prediction function

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

def predict_word(model, word_with_missing, char_to_int, int_to_char, max_word_length, guessed_letters):
    print("LSTM")
    word_encoded = [char_to_int[char] if char in char_to_int else char_to_int['0'] for char in word_with_missing]
    word_padded = pad_sequences([word_encoded], maxlen=max_word_length, padding='post')
    
    prediction = model.predict(word_padded)
    predict_vector = prediction[0]
    
    for i, char in enumerate(word_with_missing):
        if char == '0':
            probabilities = predict_vector[i]
            sorted_indices = np.argsort(-probabilities)
            for idx in sorted_indices:
                predicted_char = int_to_char[idx]
                if predicted_char != '0' and predicted_char not in guessed_letters:
                    return predicted_char
    return None  # Return None if all characters are guessed or no suitable character is found

word_with_missing = "an000"
guessed_letters = set(['e','o','i','s','t','d','a'])
predicted_char = predict_word(model, word_with_missing, char_to_int, int_to_char, max_word_length, guessed_letters)
print(predicted_char)
# Out:
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# g

# %% [markdown]
# # DAWG + LSTM Guess Algorithm
# This algo uses the DAWG data structure to prune donw the word database to reach the words that match the target word, and computes letter frequencies from them to predict the most probable letters. In case the DAWG model does not return any guesses we use the LSTM model trained on 40% masked words to predict the letter. To solidify the predictions, the LSTM takes over as soon as 70% of the word is predicted and 30% percent is left as its performance is 93% accurate given that much of letters in a word.
# This model ensures approximately 55% wins in HangMan Games.

# %%
class Node:
    def __init__(self):
        self.children = {}
        self.is_end_of_word = False

class DAWG:
    def __init__(self):
        self.root = Node()

    def add_word(self, word):
        current = self.root
        for letter in word:
            if letter not in current.children:
                current.children[letter] = Node()
            current = current.children[letter]
        current.is_end_of_word = True
    
    # search for words with similar pattern using dfs
    def generate_possible_words(self, node, partial_word):
        possible_words = []

        def dfs(current_node, current_prefix):
            if current_node.is_end_of_word:
                possible_words.append(current_prefix)
            if len(current_prefix) < len(partial_word):
                next_letter_index = len(current_prefix)
                next_letter = partial_word[next_letter_index]
                for letter, child_node in current_node.children.items():
                    if next_letter == '_' or next_letter == letter:
                        dfs(child_node, current_prefix + letter)

        dfs(node, '')
        return possible_words

    def predict_next_letter(self, partial_word, guessed_letters):
        word = partial_word.replace(" ", "")
        word = ''.join([letter if letter in guessed_letters else '_' for letter in word])
        # switch to LSTM if 70% of the word has been predicted
        if word.count('_') <= 0.3*(len(word)):
            word_with_missing = word.replace('_', '0')
            return predict_word(model, word_with_missing, char_to_int, int_to_char, max_word_length, guessed_letters)
        
        # else use the DAWG data structure to predict the letter using letter frequency
        possible_words = self.generate_possible_words(self.root, partial_word)

        letter_frequency = {}
        for word in possible_words:
            for letter in word:
                if letter not in letter_frequency and letter not in guessed_letters:
                    letter_frequency[letter] = 1
                elif letter not in guessed_letters:
                    letter_frequency[letter] += 1

        sorted_letters = sorted(letter_frequency.items(), key=lambda x: x[1], reverse=True)
        for letter, _ in sorted_letters:
            if letter not in partial_word:
                return letter
            
        # If no suitable letter is found, return a random letter not in guessed_letters
        word = partial_word.replace(" ", "")
        word = ''.join([letter if letter in guessed_letters else '_' for letter in word])
        word_with_missing = word.replace('_', '0')
        return predict_word(model, word_with_missing, char_to_int, int_to_char, max_word_length, guessed_letters)

hangman_dawg = DAWG()
for word in words:
    hangman_dawg.add_word(word)

# %% [markdown]
# # API Testing

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        
        full_dictionary_location = '/kaggle/input/english-words/words_250000_train.txt'
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        
        self.current_dictionary = []
        
    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com', 'https://sg.trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def guess(self, word):
        
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        clean_word = word[::2]
        
        # find length of passed word
        len_word = len(clean_word)

        partial_word = clean_word
        next_letter = hangman_dawg.predict_next_letter(partial_word, self.guessed_letters)
        
        guess_letter = next_letter         
        
        return guess_letter

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %%
api = HangmanAPI(access_token="api_key", timeout=2000)

# %%
for i in range(100):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    api.start_game(practice=1,verbose=True)
    
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# Successfully start a new game! Game ID: 51c477f0331a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ r _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ r _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ a _ r _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ a _ r _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e n _ a _ r _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e n t a _ r _ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'c e n t a _ r _ _ _ '}
# Guessing letter: u
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'c e n t a u r _ _ _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Guessing letter: i
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c e n t a u r _ _ _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: o
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c e n t a u r _ o _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: d
# Sever response: {'game_id': '51c477f0331a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c e n t a u r d o _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: m
# Sever response: {'game_id': '51c477f0331a', 'status': 'success', 'tries_remains': 3, 'word': 'c e n t a u r d o m '}
# Successfully finished game: 51c477f0331a
# Playing  1  th game
# Successfully start a new game! Game ID: ca40bab5bb4e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'ca40bab5bb4e', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': 'ca40bab5bb4e', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': 'ca40bab5bb4e', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e n _ _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': 'ca40bab5bb4e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e n _ _ _ _ e '}
# Guessing letter: o
# Sever response: {'game_id': 'ca40bab5bb4e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e n _ _ o _ e '}
# Guessing letter: w
# Sever response: {'game_id': 'ca40bab5bb4e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e n _ _ o _ e '}
# Guessing letter: r
# Sever response: {'game_id': 'ca40bab5bb4e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e n _ _ o _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'ca40bab5bb4e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n _ _ o _ e '}
# Guessing letter: c
# Sever response: {'game_id': 'ca40bab5bb4e', 'status': 'failed', 'tries_remains': 0, 'word': 'e n _ _ o _ e '}
# Failed game: ca40bab5bb4e. Because of: # of tries exceeded!
# Playing  2  th game
# Successfully start a new game! Game ID: a19ce35b53a8. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'a19ce35b53a8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ a '}
# Guessing letter: s
# Sever response: {'game_id': 'a19ce35b53a8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ s a '}
# Guessing letter: t
# Sever response: {'game_id': 'a19ce35b53a8', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ s a '}
# Guessing letter: d
# Sever response: {'game_id': 'a19ce35b53a8', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ s a '}
# Guessing letter: p
# Sever response: {'game_id': 'a19ce35b53a8', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ s a '}
# Guessing letter: g
# Sever response: {'game_id': 'a19ce35b53a8', 'status': 'ongoing', 'tries_remains': 3, 'word': 'g a _ s a '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: r
# Sever response: {'game_id': 'a19ce35b53a8', 'status': 'ongoing', 'tries_remains': 2, 'word': 'g a _ s a '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: l
# Sever response: {'game_id': 'a19ce35b53a8', 'status': 'ongoing', 'tries_remains': 1, 'word': 'g a _ s a '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: n
# Sever response: {'game_id': 'a19ce35b53a8', 'status': 'failed', 'tries_remains': 0, 'word': 'g a _ s a '}
# Failed game: a19ce35b53a8. Because of: # of tries exceeded!
# Playing  3  th game
# Successfully start a new game! Game ID: 67d89b10cbe0. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '67d89b10cbe0', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '67d89b10cbe0', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '67d89b10cbe0', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '67d89b10cbe0', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ s _ _ _ s '}
# Guessing letter: o
# Sever response: {'game_id': '67d89b10cbe0', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ s _ _ _ s '}
# Guessing letter: r
# Sever response: {'game_id': '67d89b10cbe0', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r _ s _ _ _ s '}
# Guessing letter: t
# Sever response: {'game_id': '67d89b10cbe0', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r _ s _ _ _ s '}
# Guessing letter: p
# Sever response: {'game_id': '67d89b10cbe0', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r _ s _ _ p s '}
# Guessing letter: c
# Sever response: {'game_id': '67d89b10cbe0', 'status': 'failed', 'tries_remains': 0, 'word': '_ r _ s _ _ p s '}
# Failed game: 67d89b10cbe0. Because of: # of tries exceeded!
# Playing  4  th game
# Successfully start a new game! Game ID: 2507205f6979. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r _ _ _ i _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r _ a _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r _ a _ i _ n '}
# Guessing letter: m
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e r _ a _ i _ n '}
# Guessing letter: t
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e r _ a t i _ n '}
# Guessing letter: p
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e r _ a t i _ n '}
# Guessing letter: s
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e r s a t i _ n '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: b
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e r s a t i _ n '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: d
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e r s a t i _ n '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: f
# Sever response: {'game_id': '2507205f6979', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e r s a t i _ n '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: c
# Sever response: {'game_id': '2507205f6979', 'status': 'failed', 'tries_remains': 0, 'word': '_ e r s a t i _ n '}
# Failed game: 2507205f6979. Because of: # of tries exceeded!
# Playing  5  th game
# Successfully start a new game! Game ID: c86c47cd4531. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ a _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r a _ _ _ e _ '}
# Guessing letter: n
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ r a n _ _ e _ '}
# Guessing letter: g
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a n _ _ e _ '}
# Guessing letter: c
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r a n c _ e _ '}
# Guessing letter: f
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a n c _ e _ '}
# Guessing letter: h
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r a n c h e _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: b
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ r a n c h e _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: p
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ r a n c h e _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: d
# Sever response: {'game_id': 'c86c47cd4531', 'status': 'failed', 'tries_remains': 0, 'word': '_ r a n c h e _ '}
# Failed game: c86c47cd4531. Because of: # of tries exceeded!
# Playing  6  th game
# Successfully start a new game! Game ID: 5b80113cc426. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ a _ e _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ _ _ a _ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ _ _ a _ e _ _ r _ '}
# Guessing letter: i
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ _ _ a _ e _ _ r _ '}
# Guessing letter: t
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ _ _ a t e _ _ r _ '}
# Guessing letter: u
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 5, 'word': 's u _ _ a t e _ _ r _ '}
# Guessing letter: m
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 4, 'word': 's u _ _ a t e _ _ r _ '}
# Guessing letter: l
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 3, 'word': 's u _ _ a t e _ _ r _ '}
# Guessing letter: d
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 2, 'word': 's u _ _ a t e _ _ r _ '}
# Guessing letter: p
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 1, 'word': 's u _ _ a t e _ _ r _ '}
# Guessing letter: b
# Sever response: {'game_id': '5b80113cc426', 'status': 'ongoing', 'tries_remains': 1, 'word': 's u b _ a t e _ _ r _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: f
# Sever response: {'game_id': '5b80113cc426', 'status': 'failed', 'tries_remains': 0, 'word': 's u b _ a t e _ _ r _ '}
# Failed game: 5b80113cc426. Because of: # of tries exceeded!
# Playing  7  th game
# Successfully start a new game! Game ID: 229ca3e31bb5. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ e '}
# Guessing letter: s
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ _ _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e n _ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e n t _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e n t _ _ l e '}
# Guessing letter: c
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e n t _ c l e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: m
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e n t _ c l e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: p
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p e n t _ c l e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: i
# Sever response: {'game_id': '229ca3e31bb5', 'status': 'success', 'tries_remains': 2, 'word': 'p e n t i c l e '}
# Successfully finished game: 229ca3e31bb5
# Playing  8  th game
# Successfully start a new game! Game ID: 29738d9e514b. # of tries remaining: 6. Word: _ _ .
# Guessing letter: c
# Sever response: {'game_id': '29738d9e514b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ '}
# Guessing letter: w
# Sever response: {'game_id': '29738d9e514b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ '}
# Guessing letter: d
# Sever response: {'game_id': '29738d9e514b', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ d '}
# Guessing letter: e
# Sever response: {'game_id': '29738d9e514b', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ d '}
# Guessing letter: h
# Sever response: {'game_id': '29738d9e514b', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ d '}
# Guessing letter: i
# Sever response: {'game_id': '29738d9e514b', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ d '}
# Guessing letter: j
# Sever response: {'game_id': '29738d9e514b', 'status': 'failed', 'tries_remains': 0, 'word': '_ d '}
# Failed game: 29738d9e514b. Because of: # of tries exceeded!
# Playing  9  th game
# Successfully start a new game! Game ID: 81a77ed85c1c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ e _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ e _ _ e _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 5, 'word': 's e _ _ _ _ _ _ e _ _ e _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 4, 'word': 's e _ _ _ _ _ _ e _ _ e _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 3, 'word': 's e _ _ _ _ _ _ e _ _ e _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 3, 'word': 's e l _ _ _ _ _ e _ _ e _ l _ '}
# Guessing letter: f
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 3, 'word': 's e l f _ _ _ _ e _ _ e _ l _ '}
# Guessing letter: d
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 3, 'word': 's e l f _ _ _ d e _ _ e d l _ '}
# Guessing letter: n
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 3, 'word': 's e l f _ _ n d e _ n e d l _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: c
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 3, 'word': 's e l f c _ n d e _ n e d l _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: o
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 3, 'word': 's e l f c o n d e _ n e d l _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: w
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 2, 'word': 's e l f c o n d e _ n e d l _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: g
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 1, 'word': 's e l f c o n d e _ n e d l _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: m
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'ongoing', 'tries_remains': 1, 'word': 's e l f c o n d e m n e d l _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: y
# Sever response: {'game_id': '81a77ed85c1c', 'status': 'success', 'tries_remains': 1, 'word': 's e l f c o n d e m n e d l y '}
# Successfully finished game: 81a77ed85c1c
# Playing  10  th game
# Successfully start a new game! Game ID: 04e1a105e257. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ a _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ a _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ a _ _ l e '}
# Guessing letter: s
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ a _ _ l e '}
# Guessing letter: n
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ a _ _ l e '}
# Guessing letter: t
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ a t _ l e '}
# Guessing letter: c
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ a t _ l e '}
# Guessing letter: i
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a _ _ a t i l e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: m
# Sever response: {'game_id': '04e1a105e257', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a _ _ a t i l e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: b
# Sever response: {'game_id': '04e1a105e257', 'status': 'failed', 'tries_remains': 0, 'word': 'a _ _ a t i l e '}
# Failed game: 04e1a105e257. Because of: # of tries exceeded!
# Playing  11  th game
# Successfully start a new game! Game ID: 05e1f2aa57bf. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '05e1f2aa57bf', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': '05e1f2aa57bf', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ a _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '05e1f2aa57bf', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ a _ _ e r '}
# Guessing letter: s
# Sever response: {'game_id': '05e1f2aa57bf', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ a _ _ e r '}
# Guessing letter: t
# Sever response: {'game_id': '05e1f2aa57bf', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ a _ t e r '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: l
# Sever response: {'game_id': '05e1f2aa57bf', 'status': 'ongoing', 'tries_remains': 6, 'word': 's l a _ t e r '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: n
# Sever response: {'game_id': '05e1f2aa57bf', 'status': 'success', 'tries_remains': 6, 'word': 's l a n t e r '}
# Successfully finished game: 05e1f2aa57bf
# Playing  12  th game
# Successfully start a new game! Game ID: f6a14d9efbbd. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e r _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e r _ a _ e '}
# Guessing letter: s
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e r _ a _ e '}
# Guessing letter: i
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e r _ a _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e r _ a _ e '}
# Guessing letter: o
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ e r _ a _ e '}
# Guessing letter: l
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ e r _ a _ e '}
# Guessing letter: m
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ e r m a _ e '}
# Guessing letter: c
# Sever response: {'game_id': 'f6a14d9efbbd', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ e r m a _ e '}
# Failed game: f6a14d9efbbd. Because of: # of tries exceeded!
# Playing  13  th game
# Successfully start a new game! Game ID: a4649156021b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ e _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ _ e _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ _ e a _ '}
# Guessing letter: d
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ _ _ e a _ '}
# Guessing letter: i
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e _ _ _ e a _ '}
# Guessing letter: n
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n _ _ e a _ '}
# Guessing letter: t
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n _ _ e a t '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: c
# Sever response: {'game_id': 'a4649156021b', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e n c _ e a t '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: h
# Sever response: {'game_id': 'a4649156021b', 'status': 'success', 'tries_remains': 1, 'word': 'e n c h e a t '}
# Successfully finished game: a4649156021b
# Playing  14  th game
# Successfully start a new game! Game ID: 6bf73154362d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '6bf73154362d', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e e _ '}
# Guessing letter: a
# Sever response: {'game_id': '6bf73154362d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e e _ '}
# Guessing letter: s
# Sever response: {'game_id': '6bf73154362d', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ e e _ '}
# Guessing letter: i
# Sever response: {'game_id': '6bf73154362d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ e e _ '}
# Guessing letter: o
# Sever response: {'game_id': '6bf73154362d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ _ _ e e _ '}
# Guessing letter: r
# Sever response: {'game_id': '6bf73154362d', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o r _ _ e e _ '}
# Guessing letter: t
# Sever response: {'game_id': '6bf73154362d', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o r _ _ e e _ '}
# Guessing letter: n
# Sever response: {'game_id': '6bf73154362d', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o r _ _ e e _ '}
# Guessing letter: c
# Sever response: {'game_id': '6bf73154362d', 'status': 'failed', 'tries_remains': 0, 'word': '_ o r _ _ e e _ '}
# Failed game: 6bf73154362d. Because of: # of tries exceeded!
# Playing  15  th game
# Successfully start a new game! Game ID: 208e9f7e406c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ e _ e '}
# Guessing letter: r
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ _ e _ e '}
# Guessing letter: a
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e _ _ _ _ e _ e '}
# Guessing letter: s
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e _ _ _ _ e _ e '}
# Guessing letter: n
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e _ _ _ _ e n e '}
# Guessing letter: l
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e l l _ _ e n e '}
# Guessing letter: o
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e l l o _ e n e '}
# Guessing letter: i
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i _ e l l o _ e n e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: m
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i _ e l l o _ e n e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: d
# Sever response: {'game_id': '208e9f7e406c', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ i _ e l l o _ e n e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: b
# Sever response: {'game_id': '208e9f7e406c', 'status': 'failed', 'tries_remains': 0, 'word': '_ i _ e l l o _ e n e '}
# Failed game: 208e9f7e406c. Because of: # of tries exceeded!
# Playing  16  th game
# Successfully start a new game! Game ID: 8d640dbd6902. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ a _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ a _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ a r _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a s _ a r _ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a s _ a r _ _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a s _ a r _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a s t a r _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd a s t a r d _ _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: i
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd a s t a r d _ _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: y
# Sever response: {'game_id': '8d640dbd6902', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd a s t a r d _ y '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: l
# Sever response: {'game_id': '8d640dbd6902', 'status': 'success', 'tries_remains': 1, 'word': 'd a s t a r d l y '}
# Successfully finished game: 8d640dbd6902
# Playing  17  th game
# Successfully start a new game! Game ID: a18b472a0b65. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ e r '}
# Guessing letter: i
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ _ _ e r '}
# Guessing letter: l
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i l _ _ e r '}
# Guessing letter: t
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i l _ t e r '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: b
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i l _ t e r '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: m
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i l _ t e r '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: d
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd i l _ t e r '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: y
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'ongoing', 'tries_remains': 1, 'word': 'd i l _ t e r '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: o
# Sever response: {'game_id': 'a18b472a0b65', 'status': 'failed', 'tries_remains': 0, 'word': 'd i l _ t e r '}
# Failed game: a18b472a0b65. Because of: # of tries exceeded!
# Playing  18  th game
# Successfully start a new game! Game ID: 586cddb99d54. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ s e _ _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ s e _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ s e _ _ i _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r _ _ s e _ _ i _ _ '}
# Guessing letter: g
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ r _ g s e _ _ i _ g '}
# Guessing letter: c
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r _ g s e _ _ i _ g '}
# Guessing letter: u
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ r u g s e _ _ i _ g '}
# Guessing letter: d
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 3, 'word': 'd r u g s e _ _ i _ g '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: n
# Sever response: {'game_id': '586cddb99d54', 'status': 'ongoing', 'tries_remains': 3, 'word': 'd r u g s e _ _ i n g '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: l
# Sever response: {'game_id': '586cddb99d54', 'status': 'success', 'tries_remains': 3, 'word': 'd r u g s e l l i n g '}
# Successfully finished game: 586cddb99d54
# Playing  19  th game
# Successfully start a new game! Game ID: e7dc4b95d996. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ a _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ a _ s '}
# Guessing letter: r
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ a _ s '}
# Guessing letter: l
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ a _ s '}
# Guessing letter: e
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e a _ s '}
# Guessing letter: t
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e a _ s '}
# Guessing letter: n
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e a n s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: b
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e a n s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: d
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e a n s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: m
# Sever response: {'game_id': 'e7dc4b95d996', 'status': 'failed', 'tries_remains': 0, 'word': '_ e a n s '}
# Failed game: e7dc4b95d996. Because of: # of tries exceeded!
# Playing  20  th game
# Successfully start a new game! Game ID: c7a429578b6a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ a _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ s _ a _ _ s e _ '}
# Guessing letter: i
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i s _ a _ i s e _ '}
# Guessing letter: m
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i s _ a m i s e _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: t
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i s _ a m i s e _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: c
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i s _ a m i s e _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: h
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i s _ a m i s e _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: l
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i s l a m i s e _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: d
# Sever response: {'game_id': 'c7a429578b6a', 'status': 'success', 'tries_remains': 2, 'word': 'i s l a m i s e d '}
# Successfully finished game: c7a429578b6a
# Playing  21  th game
# Successfully start a new game! Game ID: 777a022bcdee. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e s '}
# Guessing letter: i
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ i _ e s '}
# Guessing letter: l
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ i _ e s '}
# Guessing letter: n
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i n i _ e s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Guessing letter: m
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i n i _ e s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: p
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i n i _ e s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: b
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ i n i _ e s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: f
# Sever response: {'game_id': '777a022bcdee', 'status': 'ongoing', 'tries_remains': 1, 'word': 'f i n i _ e s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: t
# Sever response: {'game_id': '777a022bcdee', 'status': 'success', 'tries_remains': 1, 'word': 'f i n i t e s '}
# Successfully finished game: 777a022bcdee
# Playing  22  th game
# Successfully start a new game! Game ID: 19d9fc51b6c8. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '19d9fc51b6c8', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '19d9fc51b6c8', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '19d9fc51b6c8', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r e _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '19d9fc51b6c8', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '19d9fc51b6c8', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '19d9fc51b6c8', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r e _ _ _ _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '19d9fc51b6c8', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r e _ _ _ d _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '19d9fc51b6c8', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r e _ _ _ d _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '19d9fc51b6c8', 'status': 'failed', 'tries_remains': 0, 'word': 'r e _ _ _ d _ _ '}
# Failed game: 19d9fc51b6c8. Because of: # of tries exceeded!
# Playing  23  th game
# Successfully start a new game! Game ID: e0fb11e3d602. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'e0fb11e3d602', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'e0fb11e3d602', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'e0fb11e3d602', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'e0fb11e3d602', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'e0fb11e3d602', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'e0fb11e3d602', 'status': 'ongoing', 'tries_remains': 1, 'word': 'o _ _ _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'e0fb11e3d602', 'status': 'ongoing', 'tries_remains': 1, 'word': 'o _ t _ _ _ _ '}
# Guessing letter: u
# Sever response: {'game_id': 'e0fb11e3d602', 'status': 'ongoing', 'tries_remains': 1, 'word': 'o u t _ u _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'e0fb11e3d602', 'status': 'failed', 'tries_remains': 0, 'word': 'o u t _ u _ _ '}
# Failed game: e0fb11e3d602. Because of: # of tries exceeded!
# Playing  24  th game
# Successfully start a new game! Game ID: cea1c595ed2c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ e _ _ _ _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e r _ e r r _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e r _ e r r _ _ e _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e r _ e r r i _ e _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ e r _ e r r i _ e _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ e r _ e r r i _ e _ t '}
# Guessing letter: c
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ e r _ e r r i _ e _ t '}
# Guessing letter: h
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ e r _ e r r i _ e _ t '}
# Guessing letter: o
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'o _ e r _ e r r i _ e _ t '}
# Guessing letter: v
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'o v e r _ e r r i _ e _ t '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: p
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'ongoing', 'tries_remains': 1, 'word': 'o v e r _ e r r i _ e _ t '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: f
# Sever response: {'game_id': 'cea1c595ed2c', 'status': 'failed', 'tries_remains': 0, 'word': 'o v e r _ e r r i _ e _ t '}
# Failed game: cea1c595ed2c. Because of: # of tries exceeded!
# Playing  25  th game
# Successfully start a new game! Game ID: 9a71f821f80e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ _ _ i _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ _ _ i _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a r _ _ _ i r _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a r _ _ _ i r _ s '}
# Guessing letter: o
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a r _ o _ i r _ s '}
# Guessing letter: t
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a r _ o _ i r _ s '}
# Guessing letter: b
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a r b o _ i r _ s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: w
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a r b o _ i r _ s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: g
# Sever response: {'game_id': '9a71f821f80e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a r b o _ i r _ s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: m
# Sever response: {'game_id': '9a71f821f80e', 'status': 'failed', 'tries_remains': 0, 'word': 'a r b o _ i r _ s '}
# Failed game: 9a71f821f80e. Because of: # of tries exceeded!
# Playing  26  th game
# Successfully start a new game! Game ID: 7240ebba8310. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ _ _ _ _ i _ _ i _ '}
# Guessing letter: n
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ _ _ _ _ i _ _ i _ '}
# Guessing letter: a
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ a _ _ _ _ i _ _ i _ '}
# Guessing letter: s
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ a _ _ _ _ i _ _ i _ '}
# Guessing letter: l
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e _ _ a _ _ _ l i _ _ i _ '}
# Guessing letter: r
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ a _ _ _ l i _ _ i _ '}
# Guessing letter: t
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ a t _ _ l i t _ i _ '}
# Guessing letter: c
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ a t _ _ l i t _ i c '}
# Guessing letter: d
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ _ a t _ _ l i t _ i c '}
# Guessing letter: m
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e m _ a t _ _ l i t _ i c '}
# Guessing letter: h
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e m _ a t h _ l i t h i c '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: p
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e m _ a t h _ l i t h i c '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: b
# Sever response: {'game_id': '7240ebba8310', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e m b a t h _ l i t h i c '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: o
# Sever response: {'game_id': '7240ebba8310', 'status': 'success', 'tries_remains': 1, 'word': 'e m b a t h o l i t h i c '}
# Successfully finished game: 7240ebba8310
# Playing  27  th game
# Successfully start a new game! Game ID: 5a9e979fed67. # of tries remaining: 6. Word: _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '5a9e979fed67', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '5a9e979fed67', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '5a9e979fed67', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '5a9e979fed67', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '5a9e979fed67', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '5a9e979fed67', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ '}
# Failed game: 5a9e979fed67. Because of: # of tries exceeded!
# Playing  28  th game
# ...
# Guessing letter: a
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ e r _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ e r _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a l l e r _ _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: i
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a l l e r _ _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: y
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a l l e r _ y '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: t
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a l l e r _ y '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: n
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a l l e r _ y '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: c
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a l l e r _ y '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: m
# Sever response: {'game_id': 'd16c42a38c11', 'status': 'failed', 'tries_remains': 0, 'word': 'a l l e r _ y '}
# Failed game: d16c42a38c11. Because of: # of tries exceeded!
# Playing  90  th game
# Successfully start a new game! Game ID: 05d907165df4. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '05d907165df4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '05d907165df4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '05d907165df4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a r _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '05d907165df4', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a r _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '05d907165df4', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a r _ _ _ '}
# Guessing letter: d
# Sever response: {'game_id': '05d907165df4', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a r _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '05d907165df4', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a r _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '05d907165df4', 'status': 'failed', 'tries_remains': 0, 'word': '_ a r _ _ _ '}
# Failed game: 05d907165df4. Because of: # of tries exceeded!
# Playing  91  th game
# Successfully start a new game! Game ID: 0aa1b68e9063. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e r _ _ r _ '}
# Guessing letter: a
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e r _ _ r _ '}
# Guessing letter: s
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ s _ e r _ _ r _ '}
# Guessing letter: m
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ s _ e r _ _ r _ '}
# Guessing letter: t
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ s t e r _ _ r _ '}
# Guessing letter: o
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 4, 'word': 'o s t e r _ _ r _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: n
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 3, 'word': 'o s t e r _ _ r _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: v
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 2, 'word': 'o s t e r _ _ r _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: i
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'ongoing', 'tries_remains': 1, 'word': 'o s t e r _ _ r _ '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: w
# Sever response: {'game_id': '0aa1b68e9063', 'status': 'failed', 'tries_remains': 0, 'word': 'o s t e r _ _ r _ '}
# Failed game: 0aa1b68e9063. Because of: # of tries exceeded!
# Playing  92  th game
# Successfully start a new game! Game ID: 75c964d7f783. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '75c964d7f783', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '75c964d7f783', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '75c964d7f783', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a r _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '75c964d7f783', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a r _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '75c964d7f783', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a r _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '75c964d7f783', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a r _ _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '75c964d7f783', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a r _ _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '75c964d7f783', 'status': 'failed', 'tries_remains': 0, 'word': '_ a r _ _ _ _ '}
# Failed game: 75c964d7f783. Because of: # of tries exceeded!
# Playing  93  th game
# Successfully start a new game! Game ID: 78cdaff711b4. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '78cdaff711b4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '78cdaff711b4', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '78cdaff711b4', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '78cdaff711b4', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i s _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '78cdaff711b4', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i s _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '78cdaff711b4', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i s _ _ '}
# Guessing letter: c
# Sever response: {'game_id': '78cdaff711b4', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ i s _ _ '}
# Guessing letter: h
# Sever response: {'game_id': '78cdaff711b4', 'status': 'failed', 'tries_remains': 0, 'word': '_ i s _ _ '}
# Failed game: 78cdaff711b4. Because of: # of tries exceeded!
# Playing  94  th game
# Successfully start a new game! Game ID: 56a63c3b4476. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '56a63c3b4476', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': '56a63c3b4476', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '56a63c3b4476', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '56a63c3b4476', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s s e _ '}
# Guessing letter: d
# Sever response: {'game_id': '56a63c3b4476', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ s s e _ '}
# Guessing letter: o
# Sever response: {'game_id': '56a63c3b4476', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ s s e _ '}
# Guessing letter: i
# Sever response: {'game_id': '56a63c3b4476', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i s s e _ '}
# Guessing letter: m
# Sever response: {'game_id': '56a63c3b4476', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ i s s e _ '}
# Guessing letter: l
# Sever response: {'game_id': '56a63c3b4476', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ i s s e l '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Guessing letter: b
# Sever response: {'game_id': '56a63c3b4476', 'status': 'failed', 'tries_remains': 0, 'word': '_ i s s e l '}
# Failed game: 56a63c3b4476. Because of: # of tries exceeded!
# Playing  95  th game
# Successfully start a new game! Game ID: 529a6703ec46. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e '}
# Guessing letter: a
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ e '}
# Guessing letter: s
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ r _ _ e '}
# Guessing letter: o
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 3, 'word': 'o _ _ r o _ e '}
# Guessing letter: t
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 3, 'word': 'o _ t r o _ e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: u
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 3, 'word': 'o u t r o _ e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: v
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 2, 'word': 'o u t r o _ e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: p
# Sever response: {'game_id': '529a6703ec46', 'status': 'ongoing', 'tries_remains': 1, 'word': 'o u t r o _ e '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: l
# Sever response: {'game_id': '529a6703ec46', 'status': 'failed', 'tries_remains': 0, 'word': 'o u t r o _ e '}
# Failed game: 529a6703ec46. Because of: # of tries exceeded!
# Playing  96  th game
# Successfully start a new game! Game ID: 4655e777d4f7. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '4655e777d4f7', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': '4655e777d4f7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '4655e777d4f7', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '4655e777d4f7', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: i
# Sever response: {'game_id': '4655e777d4f7', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ _ e _ '}
# Guessing letter: o
# Sever response: {'game_id': '4655e777d4f7', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ _ _ e _ '}
# Guessing letter: l
# Sever response: {'game_id': '4655e777d4f7', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ _ l e _ '}
# Guessing letter: t
# Sever response: {'game_id': '4655e777d4f7', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o _ _ l e _ '}
# Guessing letter: d
# Sever response: {'game_id': '4655e777d4f7', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o _ _ l e d '}
# Guessing letter: n
# Sever response: {'game_id': '4655e777d4f7', 'status': 'failed', 'tries_remains': 0, 'word': '_ o _ _ l e d '}
# Failed game: 4655e777d4f7. Because of: # of tries exceeded!
# Playing  97  th game
# Successfully start a new game! Game ID: 30f2a671a59f. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '30f2a671a59f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e _ _ _ _ _ _ _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '30f2a671a59f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e _ _ _ r _ _ _ e r _ '}
# Guessing letter: s
# Sever response: {'game_id': '30f2a671a59f', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e _ e _ _ _ r _ _ _ e r s '}
# Guessing letter: n
# Sever response: {'game_id': '30f2a671a59f', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e _ e n _ _ r _ _ _ e r s '}
# Guessing letter: l
# Sever response: {'game_id': '30f2a671a59f', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e l e n _ _ r _ _ _ e r s '}
# Guessing letter: o
# Sever response: {'game_id': '30f2a671a59f', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e l e n o _ r _ _ _ e r s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: g
# Sever response: {'game_id': '30f2a671a59f', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e l e n o g r _ _ _ e r s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: a
# Sever response: {'game_id': '30f2a671a59f', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e l e n o g r a _ _ e r s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: p
# Sever response: {'game_id': '30f2a671a59f', 'status': 'ongoing', 'tries_remains': 6, 'word': 's e l e n o g r a p _ e r s '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Guessing letter: h
# Sever response: {'game_id': '30f2a671a59f', 'status': 'success', 'tries_remains': 6, 'word': 's e l e n o g r a p h e r s '}
# Successfully finished game: 30f2a671a59f
# Playing  98  th game
# Successfully start a new game! Game ID: be0b074d72f7. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'be0b074d72f7', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ '}
# Guessing letter: a
# Sever response: {'game_id': 'be0b074d72f7', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'be0b074d72f7', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a _ _ e r '}
# Guessing letter: s
# Sever response: {'game_id': 'be0b074d72f7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ e r '}
# Guessing letter: l
# Sever response: {'game_id': 'be0b074d72f7', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ e r '}
# Guessing letter: n
# Sever response: {'game_id': 'be0b074d72f7', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ e r '}
# Guessing letter: t
# Sever response: {'game_id': 'be0b074d72f7', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ e r '}
# Guessing letter: m
# Sever response: {'game_id': 'be0b074d72f7', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ _ e r '}
# Guessing letter: d
# Sever response: {'game_id': 'be0b074d72f7', 'status': 'failed', 'tries_remains': 0, 'word': '_ a _ _ e r '}
# Failed game: be0b074d72f7. Because of: # of tries exceeded!
# Playing  99  th game
# Successfully start a new game! Game ID: 084faaf3f585. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '084faaf3f585', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ a _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '084faaf3f585', 'status': 'ongoing', 'tries_remains': 6, 'word': 's _ a _ _ '}
# Guessing letter: p
# Sever response: {'game_id': '084faaf3f585', 'status': 'ongoing', 'tries_remains': 6, 'word': 's p a _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '084faaf3f585', 'status': 'ongoing', 'tries_remains': 5, 'word': 's p a _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '084faaf3f585', 'status': 'ongoing', 'tries_remains': 5, 'word': 's p a _ r '}
# LSTM
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Guessing letter: i
# Sever response: {'game_id': '084faaf3f585', 'status': 'success', 'tries_remains': 5, 'word': 's p a i r '}
# Successfully finished game: 084faaf3f585
